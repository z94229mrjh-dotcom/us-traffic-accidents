# %% [markdown]
# This ranks the most dangerous location-and-hour combinations across the country. It tells us exactly where and when crashes are both severe and slow to clear.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/processed/accidents.csv")

# %%
df["start_time"] = pd.to_datetime(df["start_time"], errors="coerce")
df["end_time"]   = pd.to_datetime(df["end_time"], errors="coerce")

df["duration_min"] = (
    df["end_time"] - df["start_time"]
).dt.total_seconds() / 60

df["duration_min"] = df["duration_min"].clip(lower=0, upper=360)

df["hour"] = df["start_time"].dt.hour
df["is_severe"] = (df["severity"] == 4).astype(int)

risk = (
    df.groupby(["state", "city", "hour"])
    .agg(
        n_accidents=("severity", "count"),
        severe_rate=("is_severe", "mean"),
        median_duration=("duration_min", "median")
    )
    .reset_index()
)

risk = risk[risk["n_accidents"] >= 20]

risk["duration_norm"] = risk["median_duration"] / risk["median_duration"].max()

risk["risk_score"] = (
    0.6 * risk["severe_rate"] +
    0.4 * risk["duration_norm"]
)

top20 = risk.sort_values("risk_score", ascending=False).head(20)
top20
# Out:
#       state        city  hour  n_accidents  severe_rate  median_duration  \
# 44430    tx     andrews    11           20     0.750000       179.000000
# 16998    fl   melbourne     7           26     0.192308       359.983333
# 17398    fl       ocala     0           20     0.100000       360.000000
# 1050     az   flagstaff     1           22     0.090909       360.000000
# 39903    pa      mercer    15           32     0.468750       146.566667
# 30030    nc  wilmington    16           25     0.320000       194.166667
# 45015    tx     houston     5           84     0.011905       360.000000
# 29756    nc     raleigh     0          113     0.008850       360.000000
# 28359    mt  deer_lodge    18           20     0.000000       360.000000
# 22754    la  shreveport    13           23     0.000000       360.000000
# 22756    la  shreveport    15           48     0.000000       360.000000
# 22755    la  shreveport    14           46     0.000000       360.000000
# 22757    la  shreveport    16           41     0.000000       360.000000
# 36203    ok       tulsa    14           42     0.000000       360.000000
# 36195    ok       tulsa     6           24     0.000000       360.000000
# 36194    ok       tulsa     5           22     0.000000       360.000000
# 36207    ok       tulsa    18           40     0.000000       360.000000
# 36208    ok       tulsa    19           29     0.000000       360.000000
# 8811     ca     norwalk     6           28     0.000000       360.000000
# 8810     ca     norwalk     5           26     0.000000       360.000000
#
#        duration_norm  risk_score
# 44430       0.497222    0.648889
# 16998       0.999954    0.515366
# 17398       1.000000    0.460000
# 1050        1.000000    0.454545
# 39903       0.407130    0.444102
# 30030       0.539352    0.407741
# 45015       1.000000    0.407143
# 29756       1.000000    0.405310
# 28359       1.000000    0.400000
# 22754       1.000000    0.400000
# 22756       1.000000    0.400000
# 22755       1.000000    0.400000
# 22757       1.000000    0.400000
# 36203       1.000000    0.400000
# 36195       1.000000    0.400000
# 36194       1.000000    0.400000
# 36207       1.000000    0.400000
# 36208       1.000000    0.400000
# 8811        1.000000    0.400000
# 8810        1.000000    0.400000
